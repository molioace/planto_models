# %% [markdown]
# ## 📦 Import Libraries

# %%
from data_utils import *
from base_model_utils import *
from tensorflow.keras.layers import Dense, Input, GlobalAveragePooling2D
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import Callback
from matplotlib import pyplot as plt
import numpy as np
from sklearn.metrics import classification_report
import seaborn as sns
from sklearn.metrics import confusion_matrix
from PIL import Image
import tensorflow as tf
from google.colab import files

# %% [markdown]
# ## 📊 Data Loading and Preprocessing

# %%
# !kaggle datasets download -d mohitsingh1804/plantvillage
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/mohitsingh1804/plantvillage
# License(s): GPL-2.0
# Downloading plantvillage.zip to /content
#  99% 811M/818M [00:08<00:00, 81.5MB/s]
# 100% 818M/818M [00:08<00:00, 106MB/s]

# %%
# !unzip -q /content/plantvillage.zip

# %% [markdown]
# 📁 Dataset Restructuring and Filtering
# Separated dataset into individual folders per plant.
# Only included plants with more than one disease class.
# Skipped single-class plants: Raspberry, Blueberry, Orange, Squash, Soybean.

# %%
restruct_dataset('/content/PlantVillage')
# Out:
# Processed Cherry_(including_sour): 2 classes.
# Processed Tomato: 10 classes.
# Skipping Raspberry because it has only one class.
# Processed Pepper_bell: 2 classes.
# Processed Strawberry: 2 classes.
# Processed Corn_(maize): 4 classes.
# Processed Apple: 4 classes.
# Processed Peach: 2 classes.
# Skipping Orange because it has only one class.
# Skipping Squash because it has only one class.
# Processed Potato: 3 classes.
# Skipping Blueberry because it has only one class.
# Skipping Soybean because it has only one class.
# Processed Grape: 4 classes.
# Dataset creation complete.

# %%
show_random_images('Apple')

# %% [markdown]
# # 🔄 Loading Data Generators

# %%
Apple_train_generator, Apple_val_generator, Apple_test_generator = load_data_generator('Apple')
# Out:
# Found 2376 images belonging to 4 classes.
# Found 634 images belonging to 4 classes.
# Found 161 images belonging to 4 classes.

# %% [markdown]
# # 🍎 Building the Specialized Model for Apple

# %%
base_model = load_base_model()

# %%
def build_specialized_model(base_model, num_classes):
    inputs = Input(shape=(150, 150, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=1e-4), metrics=['accuracy'])
    model.summary()
    return model

# %%
Apple_model = build_specialized_model(base_model, num_classes=4)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ functional (Functional)              │ (None, 2, 2, 256)           │         390,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 423,748 (1.62 MB)
#  Trainable params: 329,092 (1.26 MB)
#  Non-trainable params: 94,656 (369.75 KB)

# %%
plateau_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

class MyCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') >= 0.995 and logs.get('val_accuracy') >= 0.99:
            print("\nReached 99% accuracy. Stopping training!")
            self.model.stop_training = True


callback = MyCallback()

# %% [markdown]
# # 🏋️ Start Training the Model

# %%
Apple_histo = Apple_model.fit(
    Apple_train_generator,
    epochs=25,
    validation_data=Apple_val_generator,
    callbacks=[plateau_scheduler, callback]
    )
# Out:
# Epoch 1/25
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step - accuracy: 0.6117 - loss: 1.0587 - val_accuracy: 0.9527 - val_loss: 0.1529 - learning_rate: 1.0000e-04
# Epoch 2/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.9730 - loss: 0.1052 - val_accuracy: 0.9669 - val_loss: 0.0948 - learning_rate: 1.0000e-04
# Epoch 3/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.9902 - loss: 0.0531 - val_accuracy: 0.9763 - val_loss: 0.0606 - learning_rate: 1.0000e-04
# Epoch 4/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - accuracy: 0.9921 - loss: 0.0401 - val_accuracy: 0.9842 - val_loss: 0.0609 - learning_rate: 1.0000e-04
# Epoch 5/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9971 - loss: 0.0298 - val_accuracy: 0.9890 - val_loss: 0.0431 - learning_rate: 1.0000e-04
# Epoch 6/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9994 - loss: 0.0218
# Reached 99% accuracy. Stopping training!
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - accuracy: 0.9994 - loss: 0.0218 - val_accuracy: 0.9905 - val_loss: 0.0425 - learning_rate: 1.0000e-04

# %% [markdown]
# # 📈 Visualizing Model Training Performance

# %%
Apple_train_accuracy = Apple_histo.history.get('accuracy')
Apple_val_accuracy = Apple_histo.history.get('val_accuracy')

Apple_train_loss = Apple_histo.history.get('loss')
Apple_val_loss = Apple_histo.history.get('val_loss')

epochs = range(len(Apple_train_accuracy))

plt.plot(epochs, Apple_train_accuracy, 'r', label='Training_Accuracy')
plt.plot(epochs, Apple_val_accuracy, 'b', label='Validation_Accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()


plt.plot(epochs, Apple_train_loss, 'r', label='Training_Loss')
plt.plot(epochs, Apple_val_loss, 'b', label='Validation_Loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

plt.show()

# %% [markdown]
# # 📊 Model Evaluation and Confusion Matrix

# %%
Apple_model.evaluate(Apple_test_generator)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 1.0000 - loss: 0.0186
# [0.01859918236732483, 1.0]

# %%
steps = len(Apple_test_generator)

x_all = []
y_all = []

for i in range(steps):
    x_batch, y_batch = Apple_test_generator[i]
    x_all.append(x_batch)
    y_all.append(y_batch)

x_all = np.concatenate(x_all)
y_all = np.concatenate(y_all)

y_true = np.argmax(y_all, axis=1)
y_pred = np.argmax(Apple_model.predict(x_all), axis=1)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step

# %%
target_names = list(Apple_test_generator.class_indices.keys())
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#                   precision    recall  f1-score   support
#
#       Apple_scab       1.00      1.00      1.00        32
#        Black_rot       1.00      1.00      1.00        32
# Cedar_apple_rust       1.00      1.00      1.00        14
#          healthy       1.00      1.00      1.00        83
#
#         accuracy                           1.00       161
#        macro avg       1.00      1.00      1.00       161
#     weighted avg       1.00      1.00      1.00       161

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=Apple_test_generator.class_indices.keys(), yticklabels=Apple_test_generator.class_indices.keys())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # 🔨 Quantizing and Converting the Model to TFLite

# %%
Model.save(Apple_model, "Apple_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def get_quantized_model(model_name):
    model = tf.keras.models.load_model(model_name+".h5")
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS]
    quantized_tflite_model = converter.convert()

    with open(f"{model_name}.tflite", "wb") as f:
        f.write(quantized_tflite_model)

model_name = "Apple_model"
get_quantized_model("Apple_model")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Saved artifact at '/tmp/tmpelk0iqpl'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   136723546537424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546536080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546535888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546536848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546534544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546536272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546533776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546533008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546534160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473757008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546535504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723546533584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473743952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473759312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473756240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473758736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473757200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473744720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473754320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473756624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473758352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723473755856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723543082384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723306947088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723306949200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136723306947856: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# # 🧠 Model Inference with TFLite

# %%
interpreter = tf.lite.Interpreter(model_path='Apple_model.tflite')
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

input_index = input_details[0]['index']
output_index = output_details[0]['index']

# %%
image = Image.open('/content/black_rot.jpeg').resize((150, 150))
input_data = np.expand_dims(np.array(image, dtype=np.float32) / 255.0, axis=0)

interpreter.set_tensor(input_index, input_data)
interpreter.invoke()

output_data = interpreter.get_tensor(output_index)
predicted_class = np.argmax(output_data)
print("Predicted class:", target_names[predicted_class])
# Out:
# Predicted class: Black_rot

# %%
files.download('Apple_model.h5')
files.download("Apple_model.tflite")
